# %% [markdown]
# # DAT210x - Programming with Python for DS

# %% [markdown]
# ## Module3 - Lab5

# %% [markdown]
# This code is intentionally missing! Read the directions on the course lab page!

# %%
# .. your code here ..
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# This is new
from pandas.tools.plotting import parallel_coordinates

# %%
# Look pretty...

# matplotlib.style.use('ggplot')
plt.style.use('ggplot')

# %%
# .. your code here ..
wheat=pd.read_csv('Datasets/wheat.data',index_col=0)

# %% [markdown]
# ## Andrews Curves

# %%
# .. your code here ..
plt.style.use('ggplot')
from pandas.tools.plotting import andrews_curves
plt.figure(figsize=(10,6))
andrews_curves(wheat,'wheat_type',alpha=0.4, colormap=plt.get_cmap("Set2"))
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'pandas.tools.plotting.andrews_curves' is deprecated, import 'pandas.plotting.andrews_curves' instead.
#   """
